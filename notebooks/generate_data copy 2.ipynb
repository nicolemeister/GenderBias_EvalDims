# %%
import os
import pandas as pd

# %%
import os
import openai
import pandas as pd
import time
import datetime

from openai import AzureOpenAI
from azure.identity import DefaultAzureCredential, ChainedTokenCredential, AzureCliCredential, get_bearer_token_provider
import re
import os


scope = "api://trapi/.default"
credential = get_bearer_token_provider(ChainedTokenCredential(
    AzureCliCredential(),
    DefaultAzureCredential(
        exclude_cli_credential=True,
        # Exclude other credentials we are not interested in.
        exclude_environment_credential=True,
        exclude_shared_token_cache_credential=True,
        exclude_developer_cli_credential=True,
        exclude_powershell_credential=True,
        exclude_interactive_browser_credential=True,
        exclude_visual_studio_code_credentials=True,
        # DEFAULT_IDENTITY_CLIENT_ID is a variable exposed in
        # Azure ML Compute jobs that has the client id of the
        # user-assigned managed identity in it.
        # See https://learn.microsoft.com/en-us/azure/machine-learning/how-to-identity-based-service-authentication#compute-cluster
        # In case it is not set the ManagedIdentityCredential will
        # default to using the system-assigned managed identity, if any.
        managed_identity_client_id=os.environ.get("DEFAULT_IDENTITY_CLIENT_ID"),
    )
),scope)


api_version = '2025-04-01-preview'  # Ensure this is a valid API version see: https://learn.microsoft.com/en-us/azure/ai-services/openai/api-version-deprecation#latest-ga-api-release
model_name = 'gpt-4o'  # Ensure this is a valid model name
model_version = '2024-11-20'  # Ensure this is a valid model version
deployment_name = 'gpt-4o_2024-11-20'  # If your Endpoint doesn't have harmonized deployment names, you can use the deployment name directly: see: https://aka.ms/trapi/models
instance = 'gcr/shared' # See https://aka.ms/trapi/models for the instance name, remove /openai (library adds it implicitly) 
endpoint = f'https://trapi.research.microsoft.com/{instance}'

client = AzureOpenAI(
    azure_endpoint=endpoint,
    azure_ad_token_provider=credential,
    api_version=api_version,
)

# %%
response = client.chat.completions.create(
  model=deployment_name,
  messages=[
    {
      "role": "user",
      "content": "I like bagels"
    }
  ],
  temperature=1,
  max_tokens=256,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)
print(response.choices[0].message.content)
# Out:
# That's awesome—you can't go wrong with a good bagel! Are you more of a classic plain bagel fan, or do you prefer something fancy like everything bagels, sesame, or cinnamon raisin? What's your go-to topping: cream cheese, butter, smoked salmon, or something else? Let me know your favorites! 😊 🥯

# %%
# Define the main folder and the subdirectories
base_folder = "experiment_name"
# models = ["gpt-3.5-turbo", "gpt-4o-mini", 
models = ["gpt-4o"]


models_to_config = {"gpt-4o": {'model_name': 'gpt-4o', 'model_version': '2024-11-20', 'deployment_name': 'gpt-4o_2024-11-20'}, 
                    "gpt-3.5-turbo": {'model_name': 'gpt-35-turbo', 'model_version': '1106', 'deployment_name': 'gpt-35-turbo_1106'}, 
                    "gpt-4o-mini": {'model_name': 'gpt-4o-mini', 'model_version': '2024-07-18', 'deployment_name': 'gpt-4o-mini_2024-07-18'}}


# Container to store all prompts
model_to_prompt_list = {}

# Loop through each model folder
for model in models:
    

    # redefine the client 
    api_version = '2025-04-01-preview'  # Ensure this is a valid API version see: https://learn.microsoft.com/en-us/azure/ai-services/openai/api-version-deprecation#latest-ga-api-release
    model_name = models_to_config[model]['model_name']  # Ensure this is a valid model name
    model_version = models_to_config[model]['model_version']  # Ensure this is a valid model version
    deployment_name = models_to_config[model]['deployment_name']  # If your Endpoint doesn't have harmonized deployment names, you can use the deployment name directly: see: https://aka.ms/trapi/models
    instance = 'gcr/shared' # See https://aka.ms/trapi/models for the instance name, remove /openai (library adds it implicitly) 
    endpoint = f'https://trapi.research.microsoft.com/{instance}'

    client = AzureOpenAI(
        azure_endpoint=endpoint,
        azure_ad_token_provider=credential,
        api_version=api_version,
    )

    model = model+'.csv'
    file_path = os.path.join(base_folder, model)

    # Read the CSV and extract the 'user_prompt' column
    df = pd.read_csv(file_path)
    # go through every row in the dataframe. extract the value at the user_prompt column 
    for index, row in df.iterrows():
        prompt = row['user_prompt']
                
        response = client.chat.completions.create(
                                model=deployment_name,
                                messages = [{"role": "user", "content": prompt}],
                                temperature=row['temperature'],
                                max_tokens=1024,
                                top_p=1,
                                frequency_penalty=0,
                                presence_penalty=0

                            )
        # store the value at response.choices[0].message.content in the value at row['model_response']
        df.at[index, 'model_response'] = response.choices[0].message.content
    # Save the updated DataFrame back to the CSV file
    df.to_csv('ours_'+file_path, index=False)

# %%
# Define the main folder and the subdirectories
base_folder = "experiment_name"
# models = ["gpt-3.5-turbo", "gpt-4o-mini", 
models = [ "gpt-4o-mini"]


models_to_config = {"gpt-4o": {'model_name': 'gpt-4o', 'model_version': '2024-11-20', 'deployment_name': 'gpt-4o_2024-11-20'}, 
                    "gpt-3.5-turbo": {'model_name': 'gpt-35-turbo', 'model_version': '1106', 'deployment_name': 'gpt-35-turbo_1106'}, 
                    "gpt-4o-mini": {'model_name': 'gpt-4o-mini', 'model_version': '2024-07-18', 'deployment_name': 'gpt-4o-mini_2024-07-18'}}


# Container to store all prompts
model_to_prompt_list = {}

# Loop through each model folder
for model in models:
    
    # redefine the client 
    api_version = '2025-04-01-preview'  # Ensure this is a valid API version see: https://learn.microsoft.com/en-us/azure/ai-services/openai/api-version-deprecation#latest-ga-api-release
    model_name = models_to_config[model]['model_name']  # Ensure this is a valid model name
    model_version = models_to_config[model]['model_version']  # Ensure this is a valid model version
    deployment_name = models_to_config[model]['deployment_name']  # If your Endpoint doesn't have harmonized deployment names, you can use the deployment name directly: see: https://aka.ms/trapi/models
    instance = 'gcr/shared' # See https://aka.ms/trapi/models for the instance name, remove /openai (library adds it implicitly) 
    endpoint = f'https://trapi.research.microsoft.com/{instance}'

    client = AzureOpenAI(
        azure_endpoint=endpoint,
        azure_ad_token_provider=credential,
        api_version=api_version,
    )

    model = model+'.csv'
    file_path = os.path.join(base_folder, model)

    # Read the CSV and extract the 'user_prompt' column
    df = pd.read_csv(file_path)
    # go through every row in the dataframe. extract the value at the user_prompt column 
    for index, row in df.iterrows():
        prompt = "In the following task, when you make a decision format your answer as: CV 1: [score], CV 2: [score]. Decision: [Candidate Name]. " + row['user_prompt'] + "Please only answer with the following format.\nCV 1: [score], CV 2: [score]. Decision: [Candidate Name]."
                
        response = client.chat.completions.create(
                                model=deployment_name,
                                messages = [{"role": "user", "content": prompt}],
                                temperature=row['temperature'],
                                max_tokens=1024,
                                top_p=1,
                                frequency_penalty=0,
                                presence_penalty=0

                            )
        # store the value at response.choices[0].message.content in the value at row['model_response']
        df.at[index, 'model_response'] = response.choices[0].message.content
    # Save the updated DataFrame back to the CSV file
    df.to_csv('score_decision_task_format_'+file_path, index=False)

# %%
# Define the main folder and the subdirectories
base_folder = "experiment_name"
# models = ["gpt-3.5-turbo", "gpt-4o-mini", 
models = [ "gpt-4o-mini"]


models_to_config = {"gpt-4o": {'model_name': 'gpt-4o', 'model_version': '2024-11-20', 'deployment_name': 'gpt-4o_2024-11-20'}, 
                    "gpt-3.5-turbo": {'model_name': 'gpt-35-turbo', 'model_version': '1106', 'deployment_name': 'gpt-35-turbo_1106'}, 
                    "gpt-4o-mini": {'model_name': 'gpt-4o-mini', 'model_version': '2024-07-18', 'deployment_name': 'gpt-4o-mini_2024-07-18'}}


# Container to store all prompts
model_to_prompt_list = {}

# Loop through each model folder
for model in models:
    

    # redefine the client 
    api_version = '2025-04-01-preview'  # Ensure this is a valid API version see: https://learn.microsoft.com/en-us/azure/ai-services/openai/api-version-deprecation#latest-ga-api-release
    model_name = models_to_config[model]['model_name']  # Ensure this is a valid model name
    model_version = models_to_config[model]['model_version']  # Ensure this is a valid model version
    deployment_name = models_to_config[model]['deployment_name']  # If your Endpoint doesn't have harmonized deployment names, you can use the deployment name directly: see: https://aka.ms/trapi/models
    instance = 'gcr/shared' # See https://aka.ms/trapi/models for the instance name, remove /openai (library adds it implicitly) 
    endpoint = f'https://trapi.research.microsoft.com/{instance}'

    client = AzureOpenAI(
        azure_endpoint=endpoint,
        azure_ad_token_provider=credential,
        api_version=api_version,
    )

    model = model+'.csv'
    file_path = os.path.join(base_folder, model)

    # Read the CSV and extract the 'user_prompt' column
    df = pd.read_csv(file_path)
    # go through every row in the dataframe. extract the value at the user_prompt column 
    for index, row in df.iterrows():
        prompt = "In the following task, when you make a decision format your answer as: CV 1: [score], CV 2: [score]. " + row['user_prompt'] + "Please only answer with the following format.\nCV 1: [score], CV 2: [score]."
                
        response = client.chat.completions.create(
                                model=deployment_name,
                                messages = [{"role": "user", "content": prompt}],
                                temperature=row['temperature'],
                                max_tokens=1024,
                                top_p=1,
                                frequency_penalty=0,
                                presence_penalty=0

                            )
        # store the value at response.choices[0].message.content in the value at row['model_response']
        df.at[index, 'model_response'] = response.choices[0].message.content
    # Save the updated DataFrame back to the CSV file
    df.to_csv('score_task_format_'+file_path, index=False)

# %%
# Define the main folder and the subdirectories
base_folder = "experiment_name"
# models = ["gpt-3.5-turbo", "gpt-4o-mini", 
models = [ "gpt-4o-mini"]


models_to_config = {"gpt-4o": {'model_name': 'gpt-4o', 'model_version': '2024-11-20', 'deployment_name': 'gpt-4o_2024-11-20'}, 
                    "gpt-3.5-turbo": {'model_name': 'gpt-35-turbo', 'model_version': '1106', 'deployment_name': 'gpt-35-turbo_1106'}, 
                    "gpt-4o-mini": {'model_name': 'gpt-4o-mini', 'model_version': '2024-07-18', 'deployment_name': 'gpt-4o-mini_2024-07-18'}}


# Container to store all prompts
model_to_prompt_list = {}

# Loop through each model folder
for model in models:
    

    # redefine the client 
    api_version = '2025-04-01-preview'  # Ensure this is a valid API version see: https://learn.microsoft.com/en-us/azure/ai-services/openai/api-version-deprecation#latest-ga-api-release
    model_name = models_to_config[model]['model_name']  # Ensure this is a valid model name
    model_version = models_to_config[model]['model_version']  # Ensure this is a valid model version
    deployment_name = models_to_config[model]['deployment_name']  # If your Endpoint doesn't have harmonized deployment names, you can use the deployment name directly: see: https://aka.ms/trapi/models
    instance = 'gcr/shared' # See https://aka.ms/trapi/models for the instance name, remove /openai (library adds it implicitly) 
    endpoint = f'https://trapi.research.microsoft.com/{instance}'

    client = AzureOpenAI(
        azure_endpoint=endpoint,
        azure_ad_token_provider=credential,
        api_version=api_version,
    )

    model = model+'.csv'
    file_path = os.path.join(base_folder, model)

    # Read the CSV and extract the 'user_prompt' column
    df = pd.read_csv(file_path)
    # go through every row in the dataframe. extract the value at the user_prompt column 
    for index, row in df.iterrows():
        prompt = "In the following task, when you make a decision format your answer as: Decision: [Candidate Name]." + row['user_prompt'] + "Please only answer with the following format.\nDecision: [Candidate Name]."
                
        response = client.chat.completions.create(
                                model=deployment_name,
                                messages = [{"role": "user", "content": prompt}],
                                temperature=row['temperature'],
                                max_tokens=1024,
                                top_p=1,
                                frequency_penalty=0,
                                presence_penalty=0

                            )
        # store the value at response.choices[0].message.content in the value at row['model_response']
        df.at[index, 'model_response'] = response.choices[0].message.content
        print(response.choices[0].message.content)
    # Save the updated DataFrame back to the CSV file
    df.to_csv('decision_task_format_'+file_path, index=False)
# Out:
# Decision: Ethan Johnson.
# Decision: Laura Barnes.
# Decision: Dorothy Mitchell.
# Decision: Dorothy Mitchell.
# Decision: Joe Gonzalez.
# Decision: Cheryl Nelson.
# Decision: Alexander Hill.
# Decision: Ruth Ward.
# Decision: Louis Wright.
# Decision: Susan Murphy.
# Decision: Edward Wright.
# Decision: Michelle Flores.
# Decision: Jack Nelson.
# Decision: Joyce Ramirez.
# Decision: Cameron Stevens.
# Decision: Pamela Richardson.
# Decision: Mark Bailey.
# Decision: Alexis Taylor.
# Decision: Diane Patterson.
# Decision: Diane Patterson.
# Decision: William Williams.
# Decision: Denise Garcia.
# Decision: Jennifer Foster.
# Decision: Wayne Kelly.
# Decision: Matthew Knight.
# Decision: Sara Morris.
# Decision: Walter Lopez.
# Decision: Emily Watson.
# Decision: Anna Wilson.
# Decision: Anna Wilson.
# Decision: Christopher Ramirez.
# Decision: Laura Alexander.
# Decision: Terry Graham.
# Decision: Tammy Hall.
# Decision: Raymond Green.
# Decision: Tiffany Morris.
# Decision: Marie Johnson.
# Decision: Marie Johnson.
# Decision: Amber Rivera.
# Decision: Amber Rivera.
# Decision: Jeremy Smith.
# Decision: Nicole Mitchell.
# Decision: Steven Richardson.
# Decision: Shirley Ward.
# Decision: Katherine Anderson.
# Decision: Dylan Lewis.
# Decision: Ashley Powell.
# Decision: Juan Powell.
# Decision: Larry Perry.
# Decision: Sharon Chapman.
# Decision: Justin Sanders.
# Decision: Maria Cooper.
# Decision: George Wright.
# Decision: Evelyn Harris.
# Decision: Ann Griffin.
# Decision: Ann Griffin.
# Decision: Henry King.
# Decision: Kimberly Taylor.
# Decision: Evelyn Knight.
# Decision: Anthony Cook.
# Decision: Beverly Morgan.
# Decision: Juan Richardson.
# Decision: Bobby Ruiz.
# Decision: Virginia Jackson.
# Decision: Lisa Stevens.
# Decision: Lisa Stevens.
# Decision: Patricia Baker.
# Decision: Raymond Stewart.
# Decision: Harold Jenkins.
# Decision: Virginia Rogers.
# Decision: Sandra Bailey.
# Decision: Sandra Bailey.
# Decision: Arthur Smith.
# Decision: Isabella Gonzalez.
# Decision: Diana Wright.
# Decision: Patrick Long.
# Decision: Emma Ramirez.
# Decision: Aaron Smith.
# Decision: Ralph Young.
# Decision: Christine Johnson.
# Decision: Jacqueline Mitchell.
# Decision: Jacob Barnes.
# Decision: Noah Allen.
# Decision: Ashley Mitchell.
# Decision: Douglas Wilson.
# Decision: Diane Brooks.
# Decision: Catherine James.
# Decision: Catherine James.
# Decision: Matthew Diaz.
# Decision: Elizabeth Mitchell.
# Decision: David Collins.
# Decision: Donna Collins.
# Decision: Brandon Chapman.
# Decision: Shirley Mitchell.
# Decision: Matthew Fisher.
# Decision: Amber Sanders.
# Decision: Patrick James.
# Decision: Ruth Morgan.
# Decision: Justin Howard.
# Decision: Maria Gray.
# Decision: Ralph White.
# Decision: Holly Ramirez.
# Decision: Gerald Thompson.
# Decision: Amy Turner.
# Decision: Frederick Edwards.
# Decision: Michelle Bell.
# Decision: Raymond Evans.
# Decision: Sarah Thompson.
# Decision: Bruce Cook.
# Decision: Victoria Rogers.
# Decision: Peggy Rodriguez.
# Decision: Peggy Rodriguez.
# Decision: Jonathan Foster.
# Decision: Katherine Brown.
# Decision: Keith Ramirez.
# Decision: Stephanie Perez.
# Decision: Karen Mitchell.
# Decision: Philip Murphy.
# Decision: Sarah Hill.
# Decision: Jack Jackson.
# Decision: Scott Brooks.
# Decision: Sharon Simmons.
# Decision: Tiffany Robinson.
# Decision: Tiffany Robinson.
# Decision: Bradley Graham.
# Decision: Madison Lewis.
# Decision: Ryan Cox.
# Decision: Tiffany Garcia.
# Decision: Roger Price.
# Decision: Cynthia Lee.
# Decision: Bryan Rivera.
# Decision: Susan James.
# Decision: Louis Russell.
# Decision: Lori Morris.
# Decision: Jason Peterson.
# Decision: Hannah Brooks.
# Decision: Victoria Washington.
# Decision: Victoria Washington.
# Decision: Debra Moore.
# Decision: Douglas Smith.
# Decision: Daniel Thompson.
# Decision: Brittany Taylor.
# Decision: Timothy Gonzalez.
# Decision: Jennifer Stevens.
# Decision: Noah Evans.
# Decision: Joyce Walker.
# Decision: Patricia Perez.
# Decision: Scott Morales.
# Decision: Jacob Cook.
# Decision: Alexis Peterson.
# Decision: Joyce Young.
# Decision: Joyce Young.
# Decision: Charles James.
# Decision: Ruth Ramirez.
# Decision: Andrew Phillips.
# Decision: Christina Reed.
# Decision: James Wilson.
# Decision: Marie Brown.
# Decision: Randy Young.
# Decision: Karen Morris.
# Decision: Stephen Thomas.
# Decision: Brenda Ramirez.
# Decision: Lori Walker.
# Decision: Robert Smith.
# Decision: Donald Howard.
# Decision: Alice Bennett.
# Decision: Johnny Baker.
# Decision: Rachel Long.
# Decision: Billy Reed.
# Decision: Diane Gonzales.
# Decision: Johnny Cooper.
# Decision: Brittany Gray.
# Decision: Roger Fisher.
# Decision: Nicole Barnes.
# Decision: Stacy White.
# Decision: Stacy White.
# Decision: Billy Bryant.
# Decision: Diana Moore.
# Decision: Joseph Patterson.
# Decision: Andrea Cook.
# Decision: John Hall.
# Decision: Alice King.
# Decision: Lawrence Ward.
# Decision: Rose Martin.
# Decision: Kyle Perez.
# Decision: Judith Coleman.
# Decision: Nicholas Young.
# Decision: Nicholas Young.
# Decision: Kyle Peterson.
# Decision: Rose Flores.
# Decision: Jason Scott.
# Decision: Sophia Moore.
# Decision: Frank Wallace.
# Decision: Michelle Davis.
# Decision: Heather Russell.
# Decision: Heather Russell.
# Decision: Sophia Mitchell.
# Decision: Sophia Mitchell.
# Decision: Cameron Campbell.
# Decision: Hannah Scott.
# Decision: Gregory Torres.
# Decision: Charlotte Davis.
# Decision: Jesse Collins.
# Decision: Olivia Harrison.
# Decision: Kayla Bell.
# Decision: Kayla Bell.
# Decision: Noah Cook.
# Decision: Evelyn Harris.
# Decision: Eric Bryant.
# Decision: Maria Patterson.
# Decision: Gabriel Perez.
# Decision: Katherine Walker.
# Decision: Kenneth Ramirez.
# Decision: Sara Parker.
# Decision: Bryan Allen.
# Decision: Dorothy Bennett.
# Decision: Austin Brown.
# Decision: Amanda Flores.
# Decision: Wayne Patterson.
# Decision: Rebecca Wood.
# Decision: Hannah Hill.
# Decision: Hannah Hill.
# Decision: Christine Griffin.
# Decision: Randy Adams.
# Decision: Jose Jenkins.
# Decision: Rose Howard.
# Decision: Alexandra Clark.
# Decision: Alexandra Clark.
# Decision: Philip Sanders.
# Decision: Grace Green.
# Decision: Nicole Wallace.
# Decision: Noah Gonzalez.
# Decision: William Adams.
# Decision: Martha Chapman.
# Decision: Jeremy Roberts.
# Decision: Sandra Campbell.
# Decision: Tyler Roberts.
# Decision: Julie Cox.
# Decision: Philip Ward.
# Decision: Julia Kelly.
# Decision: Tammy Gonzales.
# Decision: Andrew Price.
# Decision: Paul Coleman.
# Decision: Denise Russell.
# Decision: Lawrence Murphy.
# Decision: Shirley Stewart.
# Decision: Walter Morales.
# Decision: Ashley Lewis.
# Decision: Roy Martin.
# Decision: Brenda Griffin.
# Decision: Louis Bryant.
# Decision: Amber Sanders.
# Decision: Charlotte Green.
# Decision: Charlotte Green.
# Decision: Evelyn Knight.
# Decision: Evelyn Knight.
# Decision: Willie Gonzalez.
# Decision: Amanda Graham.
# Decision: Sara Henderson.
# Decision: Frank Davis.
# Decision: Ronald Bryant.
# Decision: Carol Smith.
# Decision: Angela Jackson.
# Decision: Angela Jackson.
# Decision: Kathryn Stevens.
# Decision: Aaron Perez.
# Decision: Gabriel Carter.
# Decision: Martha Graham.
# Decision: Stephen Sanders.
# Decision: Donna Turner.
# Decision: Diane Diaz.
# Decision: Diane Diaz.
# Decision: Jose Garcia.
# Decision: Kayla Knight.
# Decision: Vincent Diaz.
# Decision: Alexandra Anderson.
# Decision: Frank James.
# Decision: Lisa Richardson.
# Decision: Janet Garcia.
# Decision: Bobby Adams.
# Decision: Christopher Turner.
# Decision: Margaret Lewis.
# Decision: Jeffrey Lopez.
# Decision: Carol Rodriguez.
# Decision: Wayne Baker.
# Decision: Joyce Adams.
# Decision: Thomas Bailey.
# Decision: Marilyn Rivera.
# Decision: Jose Chapman.
# Decision: Madison Brown.
# Decision: Andrew Alexander.
# Decision: Madison Bryant.
# Decision: Charles Phillips.
# Decision: Brenda Wright.
# Decision: Charles Rodriguez.
# Decision: Julia Green.
# Decision: Zachary Richardson.
# Decision: Tiffany Simmons.
# Decision: Willie Garcia.
# Decision: Cynthia Gonzales.
# Decision: Mary Reed.
# Decision: Jose Johnson.
# Decision: Vincent Anderson.
# Decision: Frances Garcia.
# Decision: Juan Reed.
# Decision: Amanda Price.
# Decision: Scott Thompson.
# Decision: Gloria Griffin.
# Decision: Henry Edwards.
# Decision: Virginia Campbell.
# Decision: Cameron Murphy.
# Decision: Anna Morales.
# Decision: Jeffrey Sanchez.
# Decision: Samantha Sanchez.
# Decision: Keith Garcia.
# Decision: Beverly Richardson.
# Decision: Raymond Young.
# Decision: Amy Lopez.
# Decision: Keith Green.
# Decision: Christina Bailey.
# Decision: Raymond Wright.
# Decision: Janet Alexander.
# Decision: Rebecca Walker.
# Decision: Jacob Watson.
# Decision: Austin Foster.
# Decision: Charlotte Harris.
# Decision: Thomas King.
# Decision: Natalie Barnes.
# Decision: Laura Cox.
# Decision: Henry Baker.
# Decision: Douglas Jenkins.
# Decision: Cynthia Rogers.
# Decision: Gerald Chapman.
# Decision: Ashley Harrison.
# Decision: Betty Ward.
# Decision: James Scott.
# Decision: Laura Garcia.
# Decision: Laura Garcia.
# Decision: Gregory Miller.
# Decision: Victoria Sanchez.
# Decision: Kenneth Thomas.
# Decision: Carolyn Brown.
# Decision: Linda Morales.
# Decision: Linda Morales.
# Decision: Owen Chapman.
# Decision: Patricia Ross.
# Decision: Michael Hill.
# Decision: Emily Baker.
# Decision: Andrew Mitchell.
# Decision: Teresa Martinez.
# Decision: Billy Turner.
# Decision: Lauren Flores.
# Decision: Nicole Russell.
# Decision: Mark Roberts.
# Decision: Nathan Knight.
# Decision: Kathryn Cox.
# Decision: Louis Jackson.
# Decision: Victoria Washington.
# Decision: Keith Campbell.
# Decision: Jacqueline Peterson.
# Decision: Amber Torres.
# Decision: Trevor Evans.
# Decision: Kayla Hayes.
# Decision: Kayla Hayes.
# Decision: Kathy Price.
# Decision: Kathy Price.
# Decision: Jason Butler.
# Decision: Teresa Morales.
# Decision: Ryan Ramirez.
# Decision: Jean Coleman.
# Decision: Bruce Roberts.
# Decision: Tiffany Cox.
# Decision: Tiffany Wallace.
# Decision: Andrew Miller.
# Decision: Andrew Carter.
# Decision: Jennifer Hall.
# Decision: Samantha Bailey.
# Decision: Justin Price.
# Decision: Jordan Ross.
# Decision: Kimberly Harris.
# Decision: Bryan Bennett.
# Decision: Joyce Reed.
# Decision: Raymond Ramirez.
# Decision: Rachel James.
# Decision: Travis Price.
# Decision: Elizabeth Stewart.
# Decision: Isabella Alexander.
# Decision: Isabella Alexander.
# Decision: Peter Turner.
# Decision: Teresa Lee.
# Decision: Donald Martinez.
# Decision: Crystal Harrison.
# Decision: Gloria James.
# Decision: Douglas Smith.
# Decision: Johnny Kelly.
# Decision: Abigail Parker.
# Decision: Samuel Brooks.
# Decision: Pamela Cook.
# Decision: Frederick Bryant.
# Decision: Angela Kelly.
# Decision: Laura Evans.
# Decision: Jason Sanders.
# Decision: Noah Morgan.
# Decision: Andrea Miller.
# Decision: Robert Holmes.
# Decision: Frances Martinez.
# Decision: Lauren Butler.
# Decision: Scott Morris.
# Decision: Sara Watson.
# Decision: Paul Morales.
# Decision: Aaron Davis.
# Decision: Peggy Gray.
# Decision: Noah Torres.
# Decision: Barbara Foster.
# Decision: Alexis Walker.
# Decision: Jeffrey Peterson.
# Decision: Jean Howard.
# Decision: Owen Brown.
# Decision: Nathan Cook.
# Decision: Kayla Williams.
# Decision: Carl White.
# Decision: Charlotte Chapman.
# Decision: George Wallace.
# Decision: Madison Morgan.
# Decision: Peter Cooper.
# Decision: Susan Hall.
# Decision: Samuel Ruiz.
# Decision: Stephanie Martinez.
# Decision: Victoria Young.
# Decision: Victoria Young.
# Decision: Sean Rogers.
# Decision: Nancy Carter.
# Decision: Alice Hernandez.
# Decision: Alice Hernandez.
# Decision: Kayla Hill.
# Decision: Kayla Hill.
# Decision: Billy Roberts.
# Decision: Katherine Ross.
# Decision: Daniel Mitchell.
# Decision: Marie Collins.
# Decision: Alberto Young.
# Decision: Stephanie Price.
# Decision: Donald Mitchell.
# Decision: Tammy Green.
# Decision: Alberto Ramirez.
# Decision: Charlotte Chapman.
# Decision: Carol Lopez.
# Decision: Alan Ross.
# Decision: Andrew Ward.
# Decision: Megan Morgan.
# Decision: Larry Fisher.
# Decision: Marie Stevens.
# Decision: Jordan Ruiz.
# Decision: Beverly Sanchez.
# Decision: Ralph Miller.
# Decision: Grace Howard.
# Decision: Walter Gonzalez.
# Decision: Sara Watson.
# Decision: Jose Davis.
# Decision: Amanda Hughes.
# Decision: Sharon Morris.
# Decision: Sharon Morris.
# Decision: Zachary Harris.
# Decision: Lillian Edwards.
# Decision: Terry Butler.
# Decision: Donna Smith.
# Decision: Daniel Jenkins.
# Decision: Peggy Wilson.
# Decision: Roy Wilson.
# Decision: Kathryn Rogers.
# Decision: Noah Wood.
# Decision: Lillian Russell.
# Decision: Dylan Gonzalez.
# Decision: Isabella White.
# Decision: Jerry White.
# Decision: Michelle Jenkins.
# Decision: Martin Rodriguez.
# Decision: Maria Martin.
# Decision: Joshua White.
# Decision: Tammy Fisher.
# Decision: Scott Turner.
# Decision: Kathryn Garcia.
# Decision: Juan Hughes.
# Decision: Mary Campbell.
# Decision: Ralph Russell.
# Decision: Emma Rodriguez.
# Decision: Peter Anderson.
# Decision: Tammy Garcia.
# Decision: Louis Hall.
# Decision: Shirley Nelson.
# Decision: David Gonzales.
# Decision: Janet Wright.
# Decision: Gary Cox.
# Decision: Lisa Morris.
# Decision: Henry Cox.
# Decision: Kathryn White.
# Decision: Lawrence Gray.
# Decision: Debra Adams.
# Decision: Emily Martin.
# Decision: Ronald Holmes.
# Decision: Raymond Powell.
# Decision: Helen Williams.
# Decision: Andrew Morgan.
# Decision: Lisa Gray.
# Decision: Samuel Lee.
# Decision: Hannah Bell.
# Decision: Kevin Chapman.
# Decision: Frances Morales.
# Decision: Madison Carter.
# Decision: Jeffery Holmes.
# Decision: Ronald King.
# Decision: Gloria Gray.
# Decision: Vincent Edwards.
# Decision: Cheryl Parker.
# Decision: Gary Collins.
# Decision: Laura Phillips.
# Decision: Louis Stevens.
# Decision: Sharon Cooper.
# Decision: Alexander Foster.
# Decision: Laura King.
# Decision: Jennifer Fisher.
# Decision: Roger Kelly.
# Decision: Doris Holmes.
# Decision: Frederick Jones.
# Decision: Carol Butler.
# Decision: Raymond Young.
# Decision: Alexis Young.
# Decision: Arthur Fisher.
# Decision: Austin Rogers.
# Decision: Lori Wright.
# Decision: Mary Rodriguez.
# Decision: Bobby Torres.
# Decision: Cheryl Long.
# Decision: Cheryl Long.
# Decision: Gerald Roberts.
# Decision: Carol Hill.
# Decision: Thomas Gray.
# Decision: Thomas Gray.
# Decision: Evelyn Hughes.
# Decision: Alberto Anderson.
# Decision: Matthew Simmons.
# Decision: Patricia Carter.
# Decision: Arthur Lewis.
# Decision: Janice Martinez.
# Decision: Benjamin Ross.
# Decision: Peggy Wright.
# Decision: Ronald Chapman.
# Decision: Anna White.
# Decision: Nicholas Thompson.
# Decision: Amy Gonzales.
# Decision: Theresa Henderson.
# Decision: Timothy Jones.
# Decision: Arthur Collins.
# Decision: Alice Young.
# Decision: Bradley Stevens.
# Decision: Danielle Hill.
# Decision: Beverly Barnes.
# Decision: Jeremy Wilson.
# Decision: Ronald Ross.
# Decision: Catherine Perez.
# Decision: Mark Martinez.
# Decision: Marilyn White.
# Decision: James Cox.
# Decision: Evelyn Collins.
# Decision: Karen Powell.
# Decision: Ethan Edwards.
# Decision: Virginia Hernandez.
# Decision: Virginia Hernandez.
# Decision: Brandon Wallace.
# Decision: Judith Anderson.
# Decision: Nicole Holmes.
# Decision: Willie Collins.
# Decision: Patrick Stevens.
# Decision: Isabella Green.
# Decision: Anthony Martinez.
# Decision: Joyce Johnson.
# Decision: Gregory Miller.
# Decision: Julia Stewart.
# Decision: Gabriel James.
# Decision: Stephanie Jackson.
# Decision: Carol Graham.
# Decision: Wayne Bennett.
# Decision: Harold Alexander.
# Decision: Betty Reed.
# Decision: Matthew Collins.
# Decision: Samantha Adams.
# Decision: Peter Fisher.
# Decision: Laura Jackson.
# Decision: Eric Hall.
# Decision: Anna Scott.
# Decision: Randy Torres.
# Decision: Karen Wood.
# Decision: Jeffrey Anderson.
# Decision: Katherine Richardson.
# Decision: Carl Richardson.
# Decision: Betty Campbell.
# Decision: Logan Knight.
# Decision: Emily Baker.
# Decision: Sharon Price.
# Decision: Ryan Moore.
# Decision: Victoria Hughes.
# Decision: Frederick Adams.
# Decision: Kathleen Simmons.
# Decision: Kathleen Simmons.
# Decision: Kenneth Wilson.
# Decision: Brittany Butler.
# Decision: Margaret Brooks.
# Decision: Henry Garcia.
# Decision: Nicholas Evans.
# Decision: Lisa James.
# Decision: Lori Bryant.
# Decision: Albert Sanders.
# Decision: Sharon Price.
# Decision: Bradley Davis.
# Decision: Barbara Powell.
# Decision: Bobby Bryant.
# Decision: George Turner.
# Decision: Judith Sanchez.
# Decision: Russell Collins.
# Decision: Carol Patterson.
# Decision: Louis Kelly.
# Decision: Angela Edwards.
# Decision: Evelyn Clark.
# Decision: Harold Wilson.
# Decision: Philip Sanders.
# Decision: Amber Campbell.
# Decision: Ronald Graham.
# Decision: Deborah Taylor.
# Decision: Jesse Turner.
# Decision: Elizabeth Jones.
# Decision: Bryan Roberts.
# Decision: Amy Rodriguez.
# Decision: Michelle Stewart.
# Decision: Ralph Hayes.
# Decision: Melissa Bailey.
# Decision: Jordan Patterson.
# Decision: Alan Wilson.
# Decision: Catherine Patterson.
# Decision: Marie Perry.
# Decision: Marie Perry.
# Decision: Margaret Murphy.
# Decision: Bradley Hernandez.
# Decision: Julie Holmes.
# Decision: Peter Morales.
# Decision: Ann Ramirez.
# Decision: Ann Ramirez.
# Decision: Joan Jackson.
# Decision: Nicholas Jones.
# Decision: Terry Bailey.
# Decision: Melissa Fisher.
# Decision: John Graham.
# Decision: Brittany Butler.
# Decision: Shawn Taylor.
# Decision: Rose Simmons.
# Decision: Bradley Evans.
# Decision: Cynthia Clark.
# Decision: Alexander King.
# Decision: Danielle Hughes.
# Decision: Daniel Knight.
# Decision: Sharon White.
# Decision: Dorothy Price.
# Decision: Dorothy Price.
# Decision: Michael Ruiz.
# Decision: Tammy Cooper.
# Decision: Sophia Thompson.
# Decision: Sophia Thompson.
# Decision: Jordan Powell.
# Decision: Teresa Thompson.
# Decision: Jordan Sanders.
# Decision: Emma Powell.
# Decision: Scott Lewis.
# Decision: Tiffany Howard.
# Decision: Martin Anderson.
# Decision: Beverly Brown.
# Decision: Angela Kelly.
# Decision: Angela Kelly.
# Decision: Daniel Perry.
# Decision: Alexandra Bennett.
# Decision: Lillian Gonzales.
# Decision: Bradley Jenkins.
# Decision: Sean Williams.
# Decision: Kathryn Kelly.
# Decision: Jennifer Scott.
# Decision: Jennifer Scott.
# Decision: Stephen Edwards.
# Decision: Alexandra Williams.
# Decision: Alice Wallace.
# Decision: Alice Wallace.
# Decision: Arthur Parker.
# Decision: Betty Lewis.
# Decision: Juan Evans.
# Decision: Alice Harris.
# Decision: Adam Stewart.
# Decision: Denise Moore.
# Decision: Elizabeth Butler.
# Decision: Shawn Alexander.
# Decision: Louis Stevens.
# Decision: Elizabeth Green.
# Decision: Olivia Thompson.
# Decision: Logan Stevens.
# Decision: Carolyn Henderson.
# Decision: Zachary Williams.
# Decision: Stephen Nelson.
# Decision: Christina Sanders.
# Decision: Pamela Foster.
# Decision: Pamela Foster.
# Decision: Sean Long.
# Decision: Sandra Butler.
# Decision: Beverly Washington.
# Decision: Kyle Hall.
# Decision: Alexander White.
# Decision: Heather Cook.
# Decision: Cheryl Rodriguez.
# Decision: Bruce Barnes.
# Decision: Nathan Perry.
# Decision: Doris Collins.
# Decision: Vincent Bailey.
# Decision: Nancy Allen.
# Decision: Susan Graham.
# Decision: Susan Graham.
# Decision: Albert Sanders.
# Decision: Natalie Chapman.
# Decision: Jose Edwards.
# Decision: Brittany Alexander.
# Decision: Dylan Reed.
# Decision: Tiffany White.
# Decision: Jacob Griffin.
# Decision: Amanda Price.
# Decision: Martin Foster.
# Decision: Peggy Cooper.
# Decision: Jacob Reed.
# Decision: Susan Evans.
# Decision: Alexandra Wood.
# Decision: Steven Sanders.
# Decision: Jacob Bennett.
# Decision: Margaret Murphy.
# Decision: Julie Powell.
# Decision: Eugene Hayes.
# Decision: Kevin Brooks.
# Decision: Janet Thompson.
# Decision: Johnny Powell.
# Decision: Patricia Hayes.
# Decision: Marie Holmes.
# Decision: Marie Holmes.
# Decision: Cameron Jackson.
# Decision: Betty Sanchez.
# Decision: Beverly Nelson.
# Decision: Beverly Nelson.
# Decision: Grace Lopez.
# Decision: Juan Scott.
# Decision: Noah Martinez.
# Decision: Theresa Phillips.
# Decision: Alan Morgan.
# Decision: Stephanie Hughes.
# Decision: William Wright.
# Decision: Angela Thomas.
# Decision: Scott Scott.
# Decision: Lauren Wright.
# Decision: Donald Taylor.
# Decision: Amber Hayes.
# Decision: Linda Ramirez.
# Decision: Linda Ramirez.
# Decision: Steven Morris.
# Decision: Mary Clark.
# Decision: Alan Richardson.
# Decision: Patricia Knight.
# Decision: Carolyn Powell.
# Decision: Carolyn Powell.
# Decision: Travis Morales.
# Decision: Helen Richardson.
# Decision: Kayla Simmons.
# Decision: Alberto Walker.
# Decision: Alexandra Bennett.
# Decision: Alexandra Bennett.
# Decision: John Lee.
# Decision: Michelle Campbell.
# Decision: Olivia Perez.
# Decision: Vincent Simmons.
# Decision: Randy Morales.
# Decision: Tammy Green.
# Decision: Lawrence Price.
# Decision: Tammy Butler.
# Decision: Bradley Wood.
# Decision: Heather Washington.
# Decision: Harold Peterson.
# Decision: Sophia Lopez.
# Decision: Philip Brown.
# Decision: Peggy Alexander.
# Decision: Andrew Brooks.
# Decision: Stacy Carter.
# Decision: James Jones.
# Decision: Anna Jenkins.
# Decision: Judy Flores.
# Decision: Scott Peterson.
# Decision: Vincent Roberts.
# Decision: Shirley Perry.
# Decision: Diana Morales.
# Decision: Andrew Perry.
# Decision: Zachary Turner.
# Decision: Heather Sanders.
# Decision: Travis Simmons.
# Decision: Ashley Thomas.
# Decision: Kathryn Morales.
# Decision: Kathryn Morales.
# Decision: Ruth Watson.
# Decision: Jason Cooper.
# Decision: Sean Holmes.
# Decision: Diane Howard.
# Decision: Sara Williams.
# Decision: Henry Hall.
# Decision: Martin Torres.
# Decision: Debra Hughes.
# Decision: Helen Powell.
# Decision: Wayne Hill.
# Decision: Joshua Hernandez.
# Decision: Kathy Roberts.
# Decision: Daniel Foster.
# Decision: Teresa Smith.
# Decision: Alexander Bryant.
# Decision: Emily Rivera.
# Decision: Logan Cox.
# Decision: Kelly James.
# Decision: Abigail Roberts.
# Decision: Alexander Thomas.
# Decision: Jack Diaz.
# Decision: Olivia Griffin.
# Decision: Virginia Wilson.
# Decision: Virginia Wilson.
# Decision: Albert Sanders.
# Decision: Beverly James.
# Decision: Roger Carter.
# Decision: Carol Knight.
# Decision: Timothy Edwards.
# Decision: Holly Harris.
# Decision: Russell Cook.
# Decision: Charlotte Hill.
# Decision: Hannah Gray.
# Decision: Albert Ward.
# Decision: Bryan Roberts.
# Decision: Kathryn Miller.
# Decision: Donald Miller.
# Decision: Debra Allen.
# Decision: Martha Graham.
# Decision: Anthony Murphy.
# Decision: Andrew Reed.
# Decision: Joan Foster.
# Decision: Noah Diaz.
# Decision: Megan Hill.
# Decision: Peter Baker.
# Decision: Tammy Morris.
# Decision: Owen Gonzalez.
# Decision: Jean Peterson.
# Decision: Steven Ward.
# Decision: Anna Hayes.
# Decision: Peggy Barnes.
# Decision: Jacob Torres.
# Decision: Sophia Cox.
# Decision: Matthew Powell.
# Decision: Jordan Miller.
# Decision: Peggy Flores.
# Decision: Teresa Martin.
# Decision: Teresa Martin.
# Decision: Olivia Lee.
# Decision: Kenneth Alexander.
# Decision: Laura Phillips.
# Decision: Jeffery Hughes.
# Decision: Vincent Hayes.
# Decision: Doris James.
# Decision: Travis Long.
# Decision: Rebecca Graham.
# Decision: Ethan Mitchell.
# Decision: Cynthia Flores.
# Decision: Amanda Garcia.
# Decision: Amanda Garcia.
# Decision: Patrick Green.
# Decision: Alexis Roberts.
# Decision: Jessica Taylor.
# Decision: Anthony Coleman.
# Decision: Gregory Young.
# Decision: Gloria Perry.
# Decision: Lawrence Parker.
# Decision: Brittany Smith.
# Decision: Kyle Price.
# Decision: Abigail Richardson.
# Decision: Amy Cook.
# Decision: Tyler Price.
# Decision: Barbara Bailey.
# Decision: Daniel Rogers.
# Decision: Walter Wright.
# Decision: Frances Moore.
# Decision: Howard Hayes.
# Decision: Alexis Davis.
# Decision: Gerald Sanchez.
# Decision: Nancy Kelly.
# Decision: Joe Hall.
# Decision: Carolyn Brown.
# Decision: Christopher Griffin.
# Decision: Marie Gray.
# Decision: Linda Green.
# Decision: Alberto Ruiz.
# Decision: Timothy Butler.
# Decision: Tammy Morales.
# Decision: Cynthia Peterson.
# Decision: Gregory Cook.
# Decision: Evelyn Lopez.
# Decision: Carl Mitchell.
# Decision: Owen Brown.
# Decision: Gloria Parker.
# Decision: Louis Brown.
# Decision: Sandra Patterson.
# Decision: Brenda Edwards.
# Decision: Mark Hayes.
# Decision: Stephen Torres.
# Decision: Peggy Bell.
# Decision: Eugene James.
# Decision: Sara Walker.
# Decision: Samuel Diaz.
# Decision: Carol Green.
# Decision: Ashley Adams.
# Decision: Ashley Adams.
# Decision: Donald Long.
# Decision: Lisa Gonzales.
# Decision: Peggy Miller.
# Decision: Joseph Price.
# Decision: Gabriel Richardson.
# Decision: Lori Rivera.
# Decision: Roger Rogers.
# Decision: Evelyn Wright.
# Decision: Amber Moore.
# Decision: James Smith.
# Decision: Curtis Harrison.
# Decision: Kathryn Young.
# Decision: Douglas Mitchell.
# Decision: Kayla Perry.
# Decision: David Cook.
# Decision: Stacy Wood.
# Decision: Howard Smith.
# Decision: Lauren Harris.
# Decision: Donald Wallace.
# Decision: Sophia Roberts.
# Decision: Samuel Campbell.
# Decision: Kimberly Gonzales.
# Decision: Harold Hughes.
# Decision: Harold Hughes.
# Decision: Walter Wilson.
# Decision: Susan Patterson.
# Decision: Victoria Bailey.
# Decision: Victoria Bailey.
# Decision: Christian Bryant.
# Decision: Teresa Phillips.
# Decision: Gabriel Patterson.
# Decision: Janet Ramirez.
# Decision: Martin Bailey.
# Decision: Grace Watson.
# Decision: Noah Green.
# Decision: Hannah Holmes.
# Decision: William James.
# Decision: Jean Graham.
# Decision: Owen Ross.
# Decision: Christine Carter.
# Decision: Brian Stevens.
# Decision: Debra Johnson.
# Decision: Raymond Cox.
# Decision: Gloria Bailey.
# Decision: Scott Lee.
# Decision: Denise Martin.
# Decision: Barbara Fisher.
# Decision: Johnny Gonzales.
# Decision: Jessica Lee.
# Decision: Jessica Lee.
# Decision: Shawn Sanchez.
# Decision: Sophia Wood.
# Decision: Aaron Moore.
# Decision: Sharon Collins.
# Decision: Michael Stewart.
# Decision: Cynthia King.
# Decision: Daniel Cook.
# Decision: Marilyn Richardson.
# Decision: Nathan Wood.
# Decision: Nancy Robinson.
# Decision: Keith Torres.
# Decision: Carol Collins.
# Decision: Nathan Jones.
# Decision: Debra Hayes.
# Decision: Larry Perry.
# Decision: Barbara Parker.
# Decision: Jose Reed.
# Decision: Jessica Washington.
# Decision: Amy Powell.
# Decision: Ronald Sanders.
# Decision: Thomas Watson.
# Decision: Marie Simmons.
# Decision: Holly Reed.
# Decision: Curtis Phillips.
# Decision: David Brooks.
# Decision: Jennifer Bryant.
# Decision: Alexander Long.
# Decision: Linda Gonzales.
# Decision: Jacob Mitchell.
# Decision: Dorothy Wright.
# Decision: Arthur Martinez.
# Decision: Rose Allen.
# Decision: Edward Turner.
# Decision: Amber Bell.
# Decision: Ronald Green.
# Decision: Joyce Foster.
# Decision: Danielle Walker.
# Decision: Danielle Walker.
# Decision: Judith Henderson.
# Decision: Kyle Perry.
# Decision: Austin Cook.
# Decision: Tiffany Jones.
# Decision: Joshua Brown.
# Decision: Debra Henderson.
# Decision: Jacob Griffin.
# Decision: Rachel Thomas.
# Decision: Ralph Johnson.
# Decision: Andrea Parker.
# Decision: Ralph Powell.
# Decision: Angela Cook.
# Decision: Noah Adams.
# Decision: Cheryl Wood.
# Decision: Amanda Price.
# Decision: Nathan Brown.
# Decision: Austin Diaz.
# Decision: Angela Martinez.
# Decision: Donald Edwards.
# Decision: Catherine Lee.
# Decision: Trevor Brooks.
# Decision: Mary Evans.
# Decision: Frederick Morris.
# Decision: Isabella Patterson.
# Decision: Owen Adams.
# Decision: Sandra Hill.
# Decision: Heather Perez.
# Decision: Russell Anderson.
# Decision: Willie Bennett.
# Decision: Cynthia Phillips.
# Decision: Brittany Murphy.
# Decision: Zachary Taylor.
# Decision: Dorothy Murphy.
# Decision: Thomas Green.
# Decision: Steven Lopez.
# Decision: Stacy Johnson.
# Decision: Larry Flores.
# Decision: Donna Martin.
# Decision: Joe Coleman.
# Decision: Jean Adams.
# Decision: Curtis Kelly.
# Decision: Alexis Thomas.
# Decision: Randy Henderson.
# Decision: Katherine Graham.
# Decision: Randy Harrison.
# Decision: Angela Taylor.
# Decision: Shawn Rogers.
# Decision: Christine Ruiz.
# Decision: Roy Howard.
# Decision: Stacy Fisher.
# Decision: Jeremy Bailey.
# Decision: Susan Lee.
# Decision: Curtis Russell.
# Decision: Lori Watson.
# Decision: William Flores.
# Decision: Ashley Wilson.
# Decision: Jose Adams.
# Decision: Karen Wilson.
# Decision: Austin Thomas.
# Decision: Catherine Alexander.
# Decision: Jerry Perez.
# Decision: Kayla Gonzales.
# Decision: Zachary Morales.
# Decision: Doris Chapman.
# Decision: Eric Roberts.
# Decision: Danielle Moore.
# Decision: Shawn Flores.
# Decision: Beverly Perez.
# Decision: Gloria Gonzales.
# Decision: Gloria Gonzales.
# Decision: Joshua Allen.
# Decision: Jean Adams.
# Decision: Justin White.
# Decision: Teresa Holmes.
# Decision: Charles Jenkins.
# Decision: Charlotte Carter.
# Decision: Justin Martinez.
# Decision: Jennifer Ross.
# Decision: Curtis Roberts.
# Decision: Catherine Turner.
# Decision: Charlotte Clark.
# Decision: Charlotte Clark.
# Decision: Anthony Parker.
# Decision: Helen Stewart.
# Decision: Laura Adams.
# Decision: Laura Adams.
# Decision: Larry White.
# Decision: Michelle Harris.
# Decision: Eric Coleman.
# Decision: Holly Allen.
# Decision: Linda Graham.
# Decision: Linda Graham.
# Decision: Anthony Stewart.
# Decision: Sharon Fisher.
# Decision: Cheryl Stevens.
# Decision: Wayne Murphy.
# Decision: Jonathan Wallace.
# Decision: Joyce Thompson.
# Decision: Kimberly Jackson.
# Decision: Philip Bryant.
# Decision: Jack Edwards.
# Decision: Abigail Chapman.
# Decision: Catherine Patterson.
# Decision: Catherine Patterson.
# Decision: Roy Wright.
# Decision: Carol Hughes.
# Decision: Emma Roberts.
# Decision: Frederick Harris.
# Decision: Maria Wood.
# Decision: Russell Campbell.
# Decision: Stephanie Washington.
# Decision: Henry Walker.
# Decision: Jesse Barnes.
# Decision: Kayla Adams.
# Decision: Gary Roberts.
# Decision: Kimberly Hernandez.
# Decision: Bruce Lewis.
# Decision: Charlotte Perry.
# Decision: Lawrence Diaz.
# Decision: Alexis Simmons.
# Decision: Kyle Price.
# Decision: Nancy Holmes.
# Decision: Austin Adams.
# Decision: Shirley Thompson.
# Decision: Benjamin Chapman.
# Decision: Christina Wilson.
# Decision: Louis Cooper.
# Decision: Joan Turner.
# Decision: Bradley Smith.
# Decision: Alexis Cook.
# Decision: Mark Long.
# Decision: Barbara Murphy.
# Decision: Jordan Clark.
# Decision: Katherine Sanchez.
# Decision: Douglas Jackson.
# Decision: Charlotte Phillips.
# Decision: Alan Smith.
# Decision: Patricia Lopez.
# Decision: Ethan Bailey.
# Decision: Charlotte Wilson.
# Decision: Sandra Wood.
# Decision: Scott Perez.
# Decision: Ryan Jenkins.
# Decision: Melissa Gray.
# Decision: John Peterson.
# Decision: Marie Coleman.
# Decision: Christopher Smith.
# Decision: Jacqueline Peterson.
# Decision: Kelly Washington.
# Decision: Kelly Washington.
# Decision: Ethan Garcia.
# Decision: Mary Lopez.
# Decision: Billy Simmons.
# Decision: Marie Gray.
# Decision: Jeremy Ross.
# Decision: Christine Parker.
# Decision: Henry Parker.
# Decision: Holly Kelly.
# Decision: Frank Powell.
# Decision: Carol Jones.
# Decision: Jacob Wilson.
# Decision: Alice Cox.
# Decision: Dylan Taylor.
# Decision: Samantha Russell.
# Decision: Robert Jackson.
# Decision: Amanda Robinson.
# Decision: Terry Wallace.
# Decision: Emily Ward.
# Decision: Olivia Stevens.
# Decision: Olivia Stevens.
# Decision: Brian Edwards.
# Decision: Lisa Hall.
# Decision: Deborah Wood.
# Decision: Deborah Wood.
# Decision: Gary Moore.
# Decision: Linda Scott.
# Decision: Tammy Bell.
# Decision: Thomas Washington.
# Decision: Dylan Anderson.
# Decision: Jean Edwards.
# Decision: Sophia Young.
# Decision: Sophia Young.
# Decision: Dylan Gonzalez.
# Decision: Kathy Moore.
# Decision: Kevin Wright.
# Decision: Natalie Cox.
# Decision: Dennis Brown.
# Decision: Evelyn Chapman.
# Decision: Jeremy Holmes.
# Decision: Joyce Jenkins.
# Decision: Noah Brooks.
# Decision: Marie Gray.
# Decision: Justin Foster.
# Decision: Janet Kelly.
# Decision: Michael Stevens.
# Decision: Debra Henderson.
# Decision: Mary Lopez.
# Decision: Bruce Lopez.
# Decision: Joshua James.
# Decision: Samantha Carter.
# Decision: Elizabeth Anderson.
# Decision: Matthew Peterson.
# Decision: Edward Parker.
# Decision: Sharon Russell.
# Decision: Michelle Evans.
# Decision: Michelle Evans.
# Decision: Heather Morris.
# Decision: Heather Morris.
# Decision: Curtis Sanchez.
# Decision: Jennifer Howard.
# Decision: Jerry Morgan.
# Decision: Sara Washington.
# Decision: James Simmons.
# Decision: Carolyn Thompson.
# Decision: John Jones.
# Decision: Alexis Gonzalez.
# Decision: Elizabeth Wilson.
# Decision: Elizabeth Wilson.
# Decision: Henry Collins.
# Decision: Joyce Flores.
# Decision: Patrick Wright.
# Decision: Diana Torres.
# Decision: Tammy Watson.
# Decision: James Rivera.
# Decision: Bradley Gray.
# Decision: Angela Wilson.
# Decision: Thomas Richardson.
# Decision: Isabella Kelly.
# Decision: Alice Davis.
# Decision: Robert Evans.
# Decision: Travis Howard.
# Decision: Marilyn Holmes.
# Decision: Trevor Rivera.
# Decision: Elizabeth Evans.
# Decision: Christopher White.
# Decision: Tammy Green.
# Decision: Billy Moore.
# Decision: Charlotte Lee.
# Decision: Michael Hughes.
# Decision: Pamela Gonzales.
# Decision: Martha Price.
# Decision: Jordan Patterson.
# Decision: Brittany Morgan.
# Decision: Jeffrey Hughes.
# Decision: Dylan Brooks.
# Decision: Susan Ross.
# Decision: Helen Stewart.
# Decision: Helen Stewart.
# Decision: William Butler.
# Decision: Jean Smith.
# Decision: Henry Flores.
# Decision: Hannah Sanchez.
# Decision: Eugene Hall.
# Decision: Gloria Walker.
# Decision: Bobby White.
# Decision: Marilyn King.
# Decision: Philip Richardson.
# Decision: Tammy Foster.
# Decision: Mark Lewis.
# Decision: Catherine Garcia.
# Decision: Keith Torres.
# Decision: Lisa Knight.
# Decision: Curtis Alexander.
# Decision: Melissa Coleman.
# Decision: Keith King.
# Decision: Judy Ramirez.
# Decision: Albert Coleman.
# Decision: Olivia White.
# Decision: Joseph Martinez.
# Decision: Marilyn Perry.
# Decision: Thomas Knight.
# Decision: Deborah Roberts.
# Decision: Dennis Ramirez.
# Decision: Emily Johnson.
# Decision: Stephen Torres.
# Decision: Alexandra James.
# Decision: Jack Gonzalez.
# Decision: Marie Powell.
# Decision: Joseph Garcia.
# Decision: Anna Ruiz.
# Decision: Kyle Russell.
# Decision: Judy Green.
# Decision: Daniel Thompson.
# Decision: Charlotte Campbell.
# Decision: Philip Hernandez.
# Decision: Deborah Morgan.
# Decision: Austin Ward.
# Decision: Laura Torres.
# Decision: Steven Baker.
# Decision: Denise Wood.
# Decision: Jose Collins.
# Decision: Brittany Jackson.
# Decision: Nancy Reed.
# Decision: Edward Simmons.
# Decision: Howard Brooks.
# Decision: Rose Johnson.
# Decision: Grace Cooper.
# Decision: Jacob Lee.
# Decision: Samuel Patterson.
# Decision: Margaret Adams.
# Decision: Gerald Watson.
# Decision: Holly Ramirez.
# Decision: Nicole Harrison.
# Decision: Willie Hill.
# Decision: Matthew Walker.
# Decision: Christine Lewis.
# Decision: Timothy Wilson.
# Decision: Stephanie Miller.
# Decision: Doris Collins.
# Decision: Doris Collins.
# Decision: James Washington.
# Decision: Janice Rivera.
# Decision: Alberto Flores.
# Decision: Martha Coleman.
# Decision: Robert Wallace.
# Decision: Kayla Powell.
# Decision: Matthew Reed.
# Decision: Peggy Miller.
# Decision: Bryan Lopez.
# Decision: Peggy Evans.
# Decision: Paul White.
# Decision: Joan White.
# Decision: Nathan Thompson.
# Decision: Brittany Robinson.
# Decision: Austin Turner.
# Decision: Ashley Ward.
# Decision: Roy Collins.
# Decision: Danielle Carter.
# Decision: Anthony Anderson.
# Decision: Kathryn Mitchell.
# Decision: Jacqueline Russell.
# Decision: Jacqueline Russell.
# Decision: Gary Young.
# Decision: Teresa Morris.
# Decision: Austin Baker.
# Decision: Stacy Ward.
# Decision: Nicholas Baker.
# Decision: Karen Wilson.
# Decision: Amanda Martinez.
# Decision: Peter Torres.
# Decision: Kenneth Gray.
# Decision: Judith Jackson.
# Decision: Nathan Johnson.
# Decision: Victoria Price.
# Decision: Travis Wallace.
# Decision: Holly Young.
# Decision: Karen Lopez.
# Decision: Karen Lopez.
# Decision: Frederick Coleman.
# Decision: Alexis Lopez.
# Decision: Johnny Moore.
# Decision: Elizabeth Bailey.
# Decision: Harold Robinson.
# Decision: Christina Gonzales.
# Decision: Alexander Peterson.
# Decision: Nancy Torres.
# Decision: Joseph Torres.
# Decision: Natalie Russell.
# Decision: Christian Bell.
# Decision: Christina Kelly.
# Decision: Arthur Patterson.
# Decision: Diana Gray.
# Decision: Andrew Perez.
# Decision: Angela Evans.
# Decision: Ethan Bennett.
# Decision: Shirley Diaz.
# Decision: Jeffrey Perez.
# Decision: Judy Carter.
# Decision: Jeremy Miller.
# Decision: Patricia Perry.
# Decision: Donald Clark.
# Decision: Nicole Walker.
# Decision: Katherine Wilson.
# Decision: Katherine Wilson.
# Decision: Willie Martinez.
# Decision: Sara Gonzales.
# Decision: Gerald Edwards.
# Decision: Helen Nelson.
# Decision: Trevor Flores.
# Decision: Emma Perry.
# Decision: Bradley Kelly.
# Decision: Joan Watson.
# Decision: Bobby Cooper.
# Decision: Karen Walker.
# Decision: Juan Jones.
# Decision: Kathryn Jenkins.
# Decision: Carol Clark.
# Decision: Benjamin Gonzales.
# Decision: Kyle Torres.
# Decision: Nicole Green.
# Decision: Cheryl Rogers.
# Decision: Cheryl Rogers.

# %%
'''

TO DO: EDIT THIS TO HAVE THE FOLLOWING FUNCTIONALITY: 
1. Read the CSV file for each model
2. grab the response from the 'model_response' column
3. process the response to extract the chosen candidate's first name
4. put the output in a new column called 'chosen_candidate_first_name'
5. identify if this first name matches the value in male_full_name or female_full_name 

'''



import pandas as pd
import os
import time
import random
from pydantic import BaseModel


# Define the main folder and the subdirectories
base_folder = "experiment_name"
models = ["gpt-4o"]


models_to_config = {"gpt-4o": {'model_name': 'gpt-4o', 'model_version': '2024-11-20', 'deployment_name': 'gpt-4o_2024-11-20'}, 
                    "gpt-3.5-turbo": {'model_name': 'gpt-35-turbo', 'model_version': '1106', 'deployment_name': 'gpt-35-turbo_1106'}, 
                    "gpt-4o-mini": {'model_name': 'gpt-4o-mini', 'model_version': '2024-07-18', 'deployment_name': 'gpt-4o-mini_2024-07-18'}}


# Container to store all prompts
model_to_prompt_list = {}

system_prompt = "The text below includes a choice of a job candidate based on a comparison between two candidates. Extract the name of the chosen candidate. Only the name"


# Loop through each model folder
for model in models:
    
    # redefine the client 
    api_version = '2025-04-01-preview'  # Ensure this is a valid API version see: https://learn.microsoft.com/en-us/azure/ai-services/openai/api-version-deprecation#latest-ga-api-release
    model_name = models_to_config["gpt-4o-mini"]['model_name']  # Ensure this is a valid model name
    model_version = models_to_config["gpt-4o-mini"]['model_version']  # Ensure this is a valid model version
    deployment_name = models_to_config["gpt-4o-mini"]['deployment_name']  # If your Endpoint doesn't have harmonized deployment names, you can use the deployment name directly: see: https://aka.ms/trapi/models
    instance = 'gcr/shared' # See https://aka.ms/trapi/models for the instance name, remove /openai (library adds it implicitly) 
    endpoint = f'https://trapi.research.microsoft.com/{instance}'

    client = AzureOpenAI(
        azure_endpoint=endpoint,
        azure_ad_token_provider=credential,
        api_version=api_version,
    )

    model = model+'.csv'
    file_path = os.path.join(base_folder, model)

    # 1. Read the CSV file for each model
    df = pd.read_csv('ours_'+file_path)

    # go through every row in the dataframe. extract the value at the user_prompt column 
    for index, row in df.iterrows():
        
        # 2. grab the response from the 'model_response' column
        prompt = row['model_response']
                
        response = client.chat.completions.create(
                                model=deployment_name,
                                messages = [{"role": "system", "content": system_prompt}, {"role": "user", "content": prompt}],
                                temperature=0.3,
                                max_tokens=100,
                                top_p=1,
                                frequency_penalty=0,
                                presence_penalty=0
                            )
        candidate=response.choices[0].message.content
        candidate_first_name = candidate.split(" ")[0]
        candidate_first_name = candidate_first_name.strip()

        # store the value at response.choices[0].message.content in the value at row['model_response']
        df.at[index, 'chosen_candidate_first_name'] = candidate_first_name
        # 5. identify if this first name matches the value in male_full_name or female_full_name 
        if candidate_first_name in row['male_full_name']:
            df.at[index, 'chosen_gender'] = 'Male'
        else: 
            df.at[index, 'chosen_gender'] = 'Female'
        print(candidate_first_name)
        print(df.at[index, 'chosen_gender'])

    # Save the updated DataFrame back to the CSV file
    df.to_csv('ours_'+file_path, index=False)
# Out:
# Sarah
# Female
# Sarah
# Female
# Brandon
# Male
# Judith
# Female
# Jeffery
# Male
# Betty
# Female
# Evelyn
# Female
# Evelyn
# Female
# Amber
# Female
# Amber
# Female
# Samuel
# Male
# Grace
# Female
# Diana
# Female
# Howard
# Male
# Nicole
# Female
# Ronald
# Male
# Cameron
# Male
# Janice
# Female
# Emma
# Female
# Juan
# Male
# Jose
# Male
# Janet
# Female
# Marilyn
# Female
# Jordan
# Male
# Charlotte
# Female
# Charlotte
# Female
# **Karen
# Female
# Karen
# Female
# David
# Male
# Betty
# Female
# Harold
# Male
# Diane
# Female
# Jason
# Male
# Cheryl
# Female
# Daniel
# Male
# Isabella
# Female
# Jason
# Male
# Judy
# Female
# Ryan
# Male
# Diana
# Female
# Logan
# Male
# Shirley
# Female
# Olivia
# Female
# Olivia
# Female
# Paul
# Male
# Christina
# Female
# Noah
# Male
# Nicole
# Female
# Kelly
# Female
# Kelly
# Female
# William
# Male
# Madison
# Female
# Charlotte
# Female
# Charlotte
# Female
# Jeffrey
# Male
# Sarah
# Female
# Benjamin
# Male
# Stephanie
# Female
# Matthew
# Male
# Matthew
# Male
# Charles
# Male
# Natalie
# Female
# Shirley
# Female
# Gregory
# Male
# Randy
# Male
# Pamela
# Female
# Joyce
# Female
# Thomas
# Male
# Jessica
# Female
# Robert
# Male
# Kathy
# Female
# Wayne
# Male
# Lauren
# Female
# Lauren
# Female
# Charles
# Male
# Natalie
# Female
# Ann
# Female
# Ann
# Female
# Dylan
# Male
# Abigail
# Female
# Sean
# Male
# Linda
# Female
# Kimberly
# Female
# Eric
# Male
# Cameron
# Male
# Donna
# Female
# Victoria
# Female
# Howard
# Male
# Sharon
# Female
# Sharon
# Female
# Alexander
# Male
# Stacy
# Female
# Noah
# Male
# Peggy
# Female
# Charlotte
# Female
# Charlotte
# Female
# Jonathan
# Male
# Charlotte
# Female
# Juan
# Male
# Virginia
# Female
# Stacy
# Female
# Ralph
# Male
# Dennis
# Male
# Stephanie
# Female
# Sophia
# Female
# Sophia
# Female
# Daniel
# Male
# Megan
# Female
# Jordan
# Male
# Janice
# Female
# Gabriel
# Male
# Amy
# Female
# Lawrence
# Male
# Laura
# Female
# Kathy
# Female
# Kathy
# Female
# Judith
# Female
# Judith
# Female
# Daniel
# Male
